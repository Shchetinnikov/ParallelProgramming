# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('drive/MyDrive/CUDA')

# %%
! nvcc CudaTasks.cu bmp_reader.cpp main.cpp -o main
# Out:
# CudaTasks.cu(10): warning #174-D: expression has no effect
#
# CudaTasks.cu(10): warning #174-D: expression has no effect
#
# bmp_reader.cpp: In function ‘void printBMPHeaders(BMPFile*)’:
# bmp_reader.cpp:9:10: warning: unknown escape sequence: '\]'
#     9 |  cout << "ID\[2\] = " << bmpf->bhdr.ID[0] << bmpf->bhdr.ID[1] << endl
#       |          ^~~~~~~~~~~~

# %%
! ./main sample.bmp
# Out:
# VARIANT
# X = 1019; A = 3 (cycle type); B = 9 (number of threads/processes)
#
#
# 	Total number of pixels: 1768450412

# %%
[26700 26718 26773 26815 26796 26781 26812 26787 26707]
Total result = 240889

# %%
! nvcc bmp_reader.h bmp_reader.cpp main.cu -o main
# Out:
# nvcc fatal   : Don't know what to do with 'bmp_reader.h'

# %%
! ./main sample3.bmp
# Out:
# /bin/bash: ./main: No such file or directory

# %%
! make
# Out:
# make: *** No rule to make target 'vector_add.cpp', needed by 'all'.  Stop.

# %%
# !nvidia-smi
# Out:
# Sat Apr  1 20:13:30 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
